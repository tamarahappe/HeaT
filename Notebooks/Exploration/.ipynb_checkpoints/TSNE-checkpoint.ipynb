# %%
import numpy as np 
from netCDF4 import Dataset
import os
import tensorflow as tf
import argparse
import pandas as pd
from tensorflow import keras

import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import time
import matplotlib
import matplotlib.ticker as mticker
import warnings

# %matplotlib inline
# Out:
# 2025-09-08 14:42:44.495947: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX512_VNNI AVX512_BF16
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-08 14:42:44.906834: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
# HOME = "/scistor/ivm/the410/"

HOME = "/home/thappe/" #snellius

# %%
os.chdir(f"{HOME}HeaT")
#sys.path.append(os.path.expanduser('/home/thappe/HeaT'))

from HeaT.TFrecord_utils_ERA_v2 import *

# %%
pwd
# Out:
# '/gpfs/home4/thappe/HeaT'

# %%
### GLOBAL VARIABLES IVM

os.chdir(HOME)

#IVM 
# data_path = "/scistor/ivm/the410/PAPER3"

#SNELLIUS
data_path = "/home/thappe/data/VAE_MODEL"

# %%
ls /home/thappe/data/VAE_MODEL
# Out:
# entire_model_VAE/
# ERA5_t2m_dynamic_encoded_heatwaves_L128.csv
# ERA5_t2m_dynamic_heatwaves_dates.csv
# ERA5_t2m_encoded_heatwaves_L128.csv
# ERA5_t2m_heatwaves_dates.csv
# ERA5_t2m_minus_thermo_encoded_heatwaves_L128.csv
# ERA5_t2m_minus_thermo_heatwaves_dates.csv
# GMM.pkl
# Kmeanseucl.pkl
# LENTIS_classes_VAE_L128_1000epochs.csv
# LENTIS_Heatwave_means_VAE_L128_1000epochs.csv
# VAE3D_3D_noRSDS_5d_TRANSFER_L128_B0.01_F4_AUGMENTED_final.h5

# %% [markdown]
# ## LOADING DATA  ERA5

# %%
t2m_name = "t2m_minus_thermo" 

assert t2m_name in ["t2m", "t2m_dynamic", "t2m_minus_thermo"], "data not available for this var"

VAE_model = (128, f"{data_path}/VAE3D_3D_noRSDS_5d_TRANSFER_L128_B0.01_F4_AUGMENTED_final.h5")

# %%
##load heatwave means from csv and datetime information 

heatwave_means_era5 = pd.read_csv(f'{data_path}/ERA5_{t2m_name}_encoded_heatwaves_L{VAE_model[0]}.csv', 
                             skiprows=1, header=None)

heatwave_dates_era5 = pd.read_csv(f'{data_path}/ERA5_{t2m_name}_heatwaves_dates.csv',
                             skiprows=1, header=None)

# #convert into dates from datetime 
# heatwave_dates_era5[0] = pd.to_datetime(heatwave_dates_era5[0]).dt.date
dates_era5 = heatwave_dates_era5.values.flatten()

# %%
tf_record_file = f"/home/thappe/data/tf_records/TF_record_ERA5_{t2m_name}_1940-2023_standardization_cut.tfrecord"
data = load_tfrecords_ERA5(tf_record_file)


data_parsed_era5 = data.map(parse_function_full_era5)
# Out:
# 2025-09-08 14:47:19.740348: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-09-08 14:47:19.740464: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (tcn745.local.snellius.surf.nl): /proc/driver/nvidia/version does not exist
# 2025-09-08 14:47:19.749237: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX512_VNNI AVX512_BF16
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

# %% [markdown]
# ## LOADING DATA LENTIS

# %%
ls data/VAE_MODEL
# Out:
# entire_model_VAE/
# ERA5_t2m_dynamic_encoded_heatwaves_L128.csv
# ERA5_t2m_dynamic_heatwaves_dates.csv
# ERA5_t2m_encoded_heatwaves_L128.csv
# ERA5_t2m_heatwaves_dates.csv
# ERA5_t2m_minus_thermo_encoded_heatwaves_L128.csv
# ERA5_t2m_minus_thermo_heatwaves_dates.csv
# GMM.pkl
# Kmeanseucl.pkl
# LENTIS_classes_VAE_L128_1000epochs.csv
# LENTIS_Heatwave_means_VAE_L128_1000epochs.csv
# VAE3D_3D_noRSDS_5d_TRANSFER_L128_B0.01_F4_AUGMENTED_final.h5

# %%
LENTIS_heatwave_means = pd.read_csv(f'{data_path}/LENTIS_Heatwave_means_VAE_L128_1000epochs.csv', 
                             skiprows=1, header=None) 

LENTIS_classes = pd.read_csv(f'{data_path}/LENTIS_classes_VAE_L128_1000epochs.csv', 
                             skiprows=1, header=None)

# %% [markdown]
# # TSNE here
#
# https://opentsne.readthedocs.io/en/stable/examples/01_simple_usage/01_simple_usage.html#transform

# %%
from openTSNE import TSNE

# %%
tsne = TSNE(
    perplexity=30,
    metric="euclidean",
    n_jobs=100,
    random_state=42,
    verbose=True,
)

# %% [markdown]
# ## LENTIS Transform ERA5

# %%
to_cluster = LENTIS_heatwave_means.to_numpy()

# %time embedding_train = tsne.fit(to_cluster)
# Out:
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=100, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 1.50 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.07 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=12.00, lr=1156.50 for 250 iterations...
# Iteration   50, KL divergence 5.8121, 50 iterations in 0.7272 sec
# Iteration  100, KL divergence 5.8121, 50 iterations in 0.7240 sec
# Iteration  150, KL divergence 5.8122, 50 iterations in 0.7218 sec
# Iteration  200, KL divergence 5.8121, 50 iterations in 0.7199 sec
# Iteration  250, KL divergence 5.8122, 50 iterations in 0.7243 sec
#    --> Time elapsed: 3.62 seconds
# ===> Running optimization with exaggeration=1.00, lr=13878.00 for 500 iterations...
# Iteration   50, KL divergence 4.3122, 50 iterations in 0.7150 sec
# Iteration  100, KL divergence 4.1559, 50 iterations in 0.8702 sec
# Iteration  150, KL divergence 4.0702, 50 iterations in 1.3240 sec
# Iteration  200, KL divergence 4.0145, 50 iterations in 1.8557 sec
# Iteration  250, KL divergence 3.9758, 50 iterations in 2.4060 sec
# Iteration  300, KL divergence 3.9443, 50 iterations in 2.9749 sec
# Iteration  350, KL divergence 3.9206, 50 iterations in 3.4124 sec
# Iteration  400, KL divergence 3.9006, 50 iterations in 3.9313 sec
# Iteration  450, KL divergence 3.8842, 50 iterations in 4.5346 sec
# Iteration  500, KL divergence 3.8692, 50 iterations in 5.2813 sec
#    --> Time elapsed: 27.31 seconds
# CPU times: user 1min 3s, sys: 5.23 s, total: 1min 9s
# Wall time: 32.7 s

# %%
embedding_train.shape
# Out:
# (13878, 2)

# %%
# %matplotlib inline

clusters = np.unique(LENTIS_classes)
cmap = matplotlib.cm.get_cmap('gist_rainbow', clusters.shape[0])

fig = plt.figure(figsize=(15,15))
for clusternr in clusters:
    ix= np.where(LENTIS_classes == clusternr)
    clusternr = int(clusternr)
    plt.scatter(embedding_train[ix,0], embedding_train[ix, 1], 
                color=cmap(clusternr), 
                label=f"K-means cluster {1+clusternr}") 

plt.tick_params(labelleft=False,labelbottom=False)    

plt.title("LENTIS Heatwaves T-SNE", fontsize=32)
plt.legend()

# %% [markdown]
# # embedding into LENTIS space
#
# https://opentsne.readthedocs.io/en/stable/api/index.html#openTSNE.TSNEEmbedding.transform
#
# So it only puts the points with respect to the existing space, it does not take into account the space between the points themselves

# %%
embedding_era5 = embedding_train.transform(heatwave_means_era5.to_numpy())
# Out:
# ===> Finding 15 nearest neighbors in existing embedding using Annoy approximate search...
#    --> Time elapsed: 0.06 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=4.00, lr=0.10 for 0 iterations...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.50, lr=0.10 for 250 iterations...
# Iteration   50, KL divergence 10233.1442, 50 iterations in 43.6465 sec
# Iteration  100, KL divergence 9949.2867, 50 iterations in 43.4564 sec
# Iteration  150, KL divergence 9829.0837, 50 iterations in 43.5544 sec
# Iteration  200, KL divergence 9787.3750, 50 iterations in 43.4984 sec
# Iteration  250, KL divergence 9766.9682, 50 iterations in 43.4334 sec
#    --> Time elapsed: 217.59 seconds

# %%
# %matplotlib inline

clusters = np.unique(LENTIS_classes)
cmap = matplotlib.cm.get_cmap('gist_rainbow', clusters.shape[0])

fig = plt.figure(figsize=(15,15))
for clusternr in clusters:
    ix= np.where(LENTIS_classes == clusternr)
    clusternr = int(clusternr)
    plt.scatter(embedding_train[ix,0], embedding_train[ix, 1], 
                color=cmap(clusternr), 
                s=10,
                label=f"K-means cluster {1+clusternr}") 
    
plt.scatter(embedding_era5[:,0], embedding_era5[:,1],
           color="black",
           label="ERA5")

plt.tick_params(labelleft=True,labelbottom=True)    

plt.title("LENTIS Heatwaves t-SNE \n ERA5 embedded in LENTIS phase space ", fontsize=32)
plt.legend()

# %% [markdown]
# ## ERA5 only

# %%
# %time embedding_era5_only = tsne.fit(heatwave_means_era5.to_numpy())
# Out:
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=100, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.15 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=12.00, lr=61.58 for 250 iterations...
# Iteration   50, KL divergence 1.0952, 50 iterations in 22.4790 sec
# Iteration  100, KL divergence -1.5747, 50 iterations in 7.0670 sec
# Iteration  150, KL divergence 2.9500, 50 iterations in 1.2296 sec
# Iteration  200, KL divergence 2.9500, 50 iterations in 0.3297 sec
# Iteration  250, KL divergence 2.9500, 50 iterations in 0.3354 sec
#    --> Time elapsed: 31.44 seconds
# ===> Running optimization with exaggeration=1.00, lr=739.00 for 500 iterations...
# Iteration   50, KL divergence 1.8569, 50 iterations in 17.2790 sec
# Iteration  100, KL divergence 1.7489, 50 iterations in 18.9280 sec
# Iteration  150, KL divergence 1.7034, 50 iterations in 19.0670 sec
# Iteration  200, KL divergence 1.6832, 50 iterations in 18.9153 sec
# Iteration  250, KL divergence 1.6729, 50 iterations in 18.7646 sec
# Iteration  300, KL divergence 1.6675, 50 iterations in 18.6313 sec
# Iteration  350, KL divergence 1.6647, 50 iterations in 18.6034 sec
# Iteration  400, KL divergence 1.6629, 50 iterations in 18.4486 sec
# Iteration  450, KL divergence 1.6597, 50 iterations in 18.2966 sec
# Iteration  500, KL divergence 1.6587, 50 iterations in 18.1580 sec
#    --> Time elapsed: 185.09 seconds
# CPU times: user 3min 57s, sys: 7min 17s, total: 11min 15s
# Wall time: 3min 37s

# %%
plt.scatter(embedding_era5[:,0], embedding_era5[:,1],
           color="black",
           label="ERA5 tranformed")

plt.scatter(embedding_era5_only[:,0], embedding_era5[:,1],
           color="red",
           label="ERA5 only")

plt.tick_params(labelleft=False,labelbottom=False)    

plt.title("ERA5 TSNE phase space vs embedded in LENTIS ", fontsize=32)

plt.rcParams["figure.figsize"] = (20,20)

plt.legend()
plt.show()

# %%
plt.scatter(embedding_era5_only[:,0], embedding_era5[:,1],
           color="black",
           label="ERA5")

plt.tick_params(labelleft=False,labelbottom=False)    

plt.title("ERA5 in TSNE phase space ", fontsize=32)
plt.rcParams["figure.figsize"] = (10,10)


plt.show()

# %% [markdown]
# # fit_tranform, needs a different package

# %%
from sklearn.manifold import TSNE

# %%
TSNE(
    perplexity=30,
    metric="euclidean",
    n_jobs=100,
    random_state=42,
    verbose=True,
)

# %%
tsne = TSNE(learning_rate='auto',
                init='random', perplexity=3,
                 
                 n_jobs=100,
                 random_state=42, 
                 verbose=2,)

# %%
lentis_embedding = tsne.fit_transform(LENTIS_heatwave_means.to_numpy())
# Out:
# [t-SNE] Computing 10 nearest neighbors...
# [t-SNE] Indexed 13878 samples in 0.005s...
# [t-SNE] Computed neighbors for 13878 samples in 119.698s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 13878
# [t-SNE] Computed conditional probabilities for sample 2000 / 13878
# [t-SNE] Computed conditional probabilities for sample 3000 / 13878
# [t-SNE] Computed conditional probabilities for sample 4000 / 13878
# [t-SNE] Computed conditional probabilities for sample 5000 / 13878
# [t-SNE] Computed conditional probabilities for sample 6000 / 13878
# [t-SNE] Computed conditional probabilities for sample 7000 / 13878
# [t-SNE] Computed conditional probabilities for sample 8000 / 13878
# [t-SNE] Computed conditional probabilities for sample 9000 / 13878
# [t-SNE] Computed conditional probabilities for sample 10000 / 13878
# [t-SNE] Computed conditional probabilities for sample 11000 / 13878
# [t-SNE] Computed conditional probabilities for sample 12000 / 13878
# [t-SNE] Computed conditional probabilities for sample 13000 / 13878
# [t-SNE] Computed conditional probabilities for sample 13878 / 13878
# [t-SNE] Mean sigma: 2.038329
# [t-SNE] Computed conditional probabilities in 0.046s
# [t-SNE] Iteration 50: error = 126.8129501, gradient norm = 0.0017716 (50 iterations in 1.337s)
# [t-SNE] Iteration 100: error = 126.8020859, gradient norm = 0.0004780 (50 iterations in 1.337s)
# [t-SNE] Iteration 150: error = 126.1964035, gradient norm = 0.0057347 (50 iterations in 1.067s)
# [t-SNE] Iteration 200: error = 125.2333069, gradient norm = 0.0009568 (50 iterations in 1.015s)
# [t-SNE] Iteration 250: error = 125.0785370, gradient norm = 0.0010462 (50 iterations in 0.977s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 125.078537
# [t-SNE] Iteration 300: error = 5.4879522, gradient norm = 0.0129898 (50 iterations in 0.831s)
# [t-SNE] Iteration 350: error = 4.6577582, gradient norm = 0.0129641 (50 iterations in 0.832s)
# [t-SNE] Iteration 400: error = 4.2023678, gradient norm = 0.0112283 (50 iterations in 0.844s)
# [t-SNE] Iteration 450: error = 3.9368341, gradient norm = 0.0094745 (50 iterations in 0.843s)
# [t-SNE] Iteration 500: error = 3.7502642, gradient norm = 0.0082411 (50 iterations in 0.858s)
# [t-SNE] Iteration 550: error = 3.6131771, gradient norm = 0.0073361 (50 iterations in 0.846s)
# [t-SNE] Iteration 600: error = 3.5056500, gradient norm = 0.0065634 (50 iterations in 0.852s)
# [t-SNE] Iteration 650: error = 3.4185662, gradient norm = 0.0060115 (50 iterations in 0.861s)
# [t-SNE] Iteration 700: error = 3.3459852, gradient norm = 0.0055729 (50 iterations in 0.859s)
# [t-SNE] Iteration 750: error = 3.2837226, gradient norm = 0.0052882 (50 iterations in 0.858s)
# [t-SNE] Iteration 800: error = 3.2297394, gradient norm = 0.0049696 (50 iterations in 0.856s)
# [t-SNE] Iteration 850: error = 3.1820724, gradient norm = 0.0047075 (50 iterations in 0.858s)
# [t-SNE] Iteration 900: error = 3.1395233, gradient norm = 0.0045029 (50 iterations in 0.862s)
# [t-SNE] Iteration 950: error = 3.1017094, gradient norm = 0.0042503 (50 iterations in 0.869s)
# [t-SNE] Iteration 1000: error = 3.0670779, gradient norm = 0.0041279 (50 iterations in 0.878s)
# [t-SNE] KL divergence after 1000 iterations: 3.067078

# %%
era5_embedding_refit = tsne.fit_transform(heatwave_means_era5.to_numpy())
# Out:
# [t-SNE] Computing 10 nearest neighbors...
# [t-SNE] Indexed 739 samples in 0.001s...
# [t-SNE] Computed neighbors for 739 samples in 0.030s...
# [t-SNE] Computed conditional probabilities for sample 739 / 739
# [t-SNE] Mean sigma: 3.213681
# [t-SNE] Computed conditional probabilities in 0.003s
# [t-SNE] Iteration 50: error = 93.5450287, gradient norm = 0.0722130 (50 iterations in 0.064s)
# [t-SNE] Iteration 100: error = 93.2974167, gradient norm = 0.0708663 (50 iterations in 0.058s)
# [t-SNE] Iteration 150: error = 91.9727325, gradient norm = 0.0924030 (50 iterations in 0.055s)
# [t-SNE] Iteration 200: error = 91.8147507, gradient norm = 0.1583209 (50 iterations in 0.054s)
# [t-SNE] Iteration 250: error = 92.0981827, gradient norm = 0.0781492 (50 iterations in 0.055s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 92.098183
# [t-SNE] Iteration 300: error = 2.1085067, gradient norm = 0.0289831 (50 iterations in 0.048s)
# [t-SNE] Iteration 350: error = 1.7291644, gradient norm = 0.0159871 (50 iterations in 0.046s)
# [t-SNE] Iteration 400: error = 1.5720245, gradient norm = 0.0130596 (50 iterations in 0.044s)
# [t-SNE] Iteration 450: error = 1.4883089, gradient norm = 0.0104484 (50 iterations in 0.044s)
# [t-SNE] Iteration 500: error = 1.4378799, gradient norm = 0.0089345 (50 iterations in 0.044s)
# [t-SNE] Iteration 550: error = 1.4036804, gradient norm = 0.0074032 (50 iterations in 0.044s)
# [t-SNE] Iteration 600: error = 1.3805512, gradient norm = 0.0061990 (50 iterations in 0.045s)
# [t-SNE] Iteration 650: error = 1.3639745, gradient norm = 0.0057296 (50 iterations in 0.044s)
# [t-SNE] Iteration 700: error = 1.3513988, gradient norm = 0.0052785 (50 iterations in 0.044s)
# [t-SNE] Iteration 750: error = 1.3421800, gradient norm = 0.0046087 (50 iterations in 0.044s)
# [t-SNE] Iteration 800: error = 1.3337778, gradient norm = 0.0072171 (50 iterations in 0.044s)
# [t-SNE] Iteration 850: error = 1.3259779, gradient norm = 0.0038889 (50 iterations in 0.045s)
# [t-SNE] Iteration 900: error = 1.3207098, gradient norm = 0.0034921 (50 iterations in 0.044s)
# [t-SNE] Iteration 950: error = 1.3161470, gradient norm = 0.0034612 (50 iterations in 0.044s)
# [t-SNE] Iteration 1000: error = 1.3130620, gradient norm = 0.0027721 (50 iterations in 0.044s)
# [t-SNE] KL divergence after 1000 iterations: 1.313062

# %%
# plt.scatter(lentis_embedding[:,0], lentis_embedding[:,1],
#            color="blue",
#             s=10,
#            label="LENTIS")

clusters = np.unique(LENTIS_classes)
cmap = matplotlib.cm.get_cmap('gist_rainbow', clusters.shape[0])

fig = plt.figure(figsize=(15,15))
for clusternr in clusters:
    ix= np.where(LENTIS_classes == clusternr)
    clusternr = int(clusternr)
    plt.scatter(lentis_embedding[ix,0], lentis_embedding[ix, 1], 
                color=cmap(clusternr), 
                s=10,
                label=f"K-means cluster {1+clusternr}") 


plt.scatter(era5_embedding_refit[:,0], era5_embedding_refit[:,1],
           color="black",
           label="ERA5 refitted")

plt.tick_params(labelleft=False,labelbottom=False)    

plt.title("ERA5 refitted on LENTIS TSNE phase space ", fontsize=32)

plt.rcParams["figure.figsize"] = (12,12)

plt.legend()
plt.show()
